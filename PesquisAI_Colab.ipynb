# %% [markdown]
# # 👨‍🔬 PesquisAI — Agente de IA para Pesquisadores Científicos
#
# Registro SisPPG/UFV nº **10356285004** — [Verificar autenticidade](http://sisppg.ufv.br)
#
# Execute a célula abaixo e aguarde. Um botão aparecerá quando tudo estiver pronto.
#
# ---

# %%
import os, sys, subprocess

# Repositório com todo o código
REPO_URL = "https://github.com/gustavobraga-byte/PesquisAI.git"
WORK_DIR = "/tmp/pesquisai"

def show_loading():
    from IPython.display import display, HTML
    display(HTML("""
<style>
@keyframes spin { 0% { transform: rotate(0deg); } 100% { transform: rotate(360deg); } }
@keyframes pulse { 0%, 100% { opacity: 1; } 50% { opacity: 0.5; } }
.loading-container { display: flex; flex-direction: column; align-items: center; justify-content: center; padding: 50px; }
.spinner { width: 48px; height: 48px; border: 4px solid rgba(79,195,247,0.15); border-top-color: #4fc3f7; border-radius: 50%; animation: spin 1s linear infinite; margin-bottom: 20px; }
.loading-text { color: #4fc3f7; font-family: monospace; font-size: 15px; animation: pulse 1.5s ease-in-out infinite; }
</style>
<div class=\"loading-container\"><div class=\"spinner\"></div><div class=\"loading-text\">Carregando o PesquisAI...</div></div>
"""))

# Mostrar loading
show_loading()

# Limpar diretório anterior se existir
import shutil
if os.path.exists(WORK_DIR):
    shutil.rmtree(WORK_DIR)

# Clonar repositório
subprocess.run(["git", "clone", "--depth", "1", REPO_URL, WORK_DIR], capture_output=True)

# Mudar para o diretório e executar
os.chdir(WORK_DIR)
sys.path.insert(0, WORK_DIR)

# Importar e rodar tudo (usa modo rápido com run_fast)
from main import run
run()
